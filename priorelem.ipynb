# %% [markdown]
# count the number of elem which are greather than prior elem

# %%
arr=list(map(int,input().split()))
count=1
maxe=arr[1]
for i in range(len(arr)-1):
    if arr[i]>arr[i+1]:
        maxe=arr[i]
        count=count+1
print(count)
# Out:
# 2

# %%
arr=list(map(int,input().split()))
count=1
maxe=arr[1]
for i in range(len(arr)-1):
    if arr[i]>arr[i+1]:
        maxe=arr[i]
        count=count+1
print(count)
# Out:
# 3

# %%
arr=list(map(int,input().split()))
count=1
maxi=arr[0]
for i in range(1,len(arr)):
    if arr[i]>maxi:
        maxi=arr[i]
        count+=1
print(count)
# Out:
# 3
