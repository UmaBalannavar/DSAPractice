# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n=10 
summ=0
for i in range(1,11):
    summ=summ+n*i
print(summ)
# Out:
# 550

# %% [markdown]
# order of n O(n)

# %%
num=10
n=10 
#n is num of multiples
nums=num*(n*(n+1)/2)
print(nums)
# Out:
# 550.0

# %%
num=10
n=10
print(num*(n*(n+1)/2))
# Out:
# 550.0

# %% [markdown]
# O(1)

# %%
n=10
print(10*(n*(n+1)/2))
#10 coz,we need 10multiples of 10
# Out:
# 550.0
